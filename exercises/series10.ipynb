# %% [markdown]
# # Serie 10
# ## Aufgabe 10.1
# Untenstehend finden Sie mehrere Beispiele für Vergleiche von 2 Stichproben. Beantworten Sie für jedes Beispiel kurz die folgenden Fragen:
# 1. Handelt es sich um gepaarte oder um ungepaarte Stichproben? Begründen Sie!
# 1. Ist der Test einseitig oder zweiseitig durchzuführen? Begründen Sie!
# 1. Wie lautet die Nullhypothese in Worten?
# 1. Wie lautet die Alternativhypothese in Worten?

# %% [markdown]
# In einem Experiment sollte der Effekt von Zigarettenrauchen auf Blutplättchenanhäufungen untersucht werden. Dazu wurden 11 Probanden vor und nach dem Rauchen einer Zigarette Blutproben entnommen, und es wurde gemessen, wie stark sich die Blutplättchen anhäuften. Es interessiert, ob sich Blutplättchen durch das Rauchen vermehrt anhäufen.

# %% [markdown]
# 1. Es handelt sich um **gepaarte** Stichproben, für einen Vergleich müssen beide Messungen vorhanden sein
# 1. einseitig, weil gemessen wurde ob sich die Plättchen *anhäuften*
# 1. die Anzahl Blutplättchen bleibt gleich
# 1. die Anzahl Blutplättchen ist grösser als $H_0$

# %% [markdown]
# Die nächsten Daten sind aus einer Studie von Charles Darwin über die Fremd- und Selbstbefruchtung. 15 Paare von Setzlingen mit demselben Alter, je einer durch Selbst- und einer durch Fremdbefruchtung produziert, wurden gezüchtet. Beide Teile je eines Paares hatten nahezu gleiche Bedingungen. Das Ziel bestand darin zu sehen, ob die fremdbefruchteten Pflanzen mehr Lebenskraft besitzen als die selbstbefruchteten (d.h., ob sie grösser werden). Es wurden die Höhen jeder Pflanze nach einer fixen Zeitspanne gemessen.

# %% [markdown]
# 1. Es handelt sich um eine **gepaarte** Stichproben, zu jeder Grösse eines fremdbefruchteten gehört eine Messung des selbstbefruchteten Setzlings.
# 1. einseitig, weil die Frage geklärt wurde welche Sorte grösser wurde
# 1. die fremdbefruchteten Pflanzen haben mehr Lebenskraft (Grösse)
# 1. die selbstbefruchteten Pflanzen haben mehr Lebenskraft

# %% [markdown]
# Beeinflusst der Kalziumgehalt in der Nahrung den systolischen Blutdruck? Zur Überprüfung dieser Frage wurde einer Versuchsgruppe von 10 Männern während 12 Wochen ein Kalziumzusatz verabreicht. Einer Kontrollgruppe von 11 Männern gab man ein Placebopräparat.

# %% [markdown]
# 1. Es ist eine **ungepaarte** Stichprobe, die Präparate werden an verschiedene Gruppengrössen verteilt wurden
# 1. zweiseitig, der systolische Blutdruck kann sich in beide Richtungen verändern
# 1. der systolischen Blutdruck wird von Kalzium beeiflusst
# 1. der systolische Blutdruck bleibt gleich

# %% [markdown]
# In einem Experiment wurde untersucht, ob Mäuse zwei Formen von Eisen ($Fe^{2+}$ und $Fe^{3+}$) unterschiedlich gut aufnehmen. Dazu wurden 36 Mäuse in zwei Gruppen zu je 18 unterteilt und die eine Gruppe mit $Fe^{2+}$ und die andere mit $Fe^{3+}$ "gefüttert. Da das Eisen radioaktiv markiert war, konnte sowohl die Anfangskonzentration wie auch die Konzentration einige Zeit später gemessen werden. Daraus wurde für jede Maus der Anteil des aufgenommenen Eisens berechnet.

# %% [markdown]
# 1. Ist eine **gepaarte** Stichprobe, die Konzentration vor und nach der Einnahme wurde gemessen
# 1. zweiseitig, die Messungen können in beide Richtungen ausschlagen
# 1. Mäuse können versch. Eisen identisch aufnehmen
# 1. Eine Eisenvariante kann von Mäusen besser aufgenommen werden

# %% [markdown]
# # Aufgabe 10.2
# Zwei Tiefen-Messgeräte messen für die Tiefe einer Gesteins-Schicht an 9 verschiedenen Orten die folgenden Werte: Kennzahlen für die Differenz:
# ![series_10.2.png](attachment:95eb07ab-9f3f-46ae-b1f3-e8ef8afeaee6.png)
# $\bar{d}_n$ beträgt −5.78, die Standardabweichung $\sigma_D$ = 6.2. Es wird vermutet, dass Gerät B systematisch grössere Werte misst. Bestätigen die Messwerte diese Vermutung oder ist eine zufällige Schwankung als Erklärung plausibel?

# %% [markdown]
# a) Handelt es sich um verbundene (gepaarte) oder um unabhängige Stichproben?

# %% [markdown]
# Es handelt sich um eine **gepaarte** Stichprobe, weil die Messung mit beiden Geräten am selben Ort gemacht wird.

# %% [markdown]
# b) Führen Sie einen t-Test auf dem Niveau $\alpha=0.05$ durch. Formulieren Sie explizit: Modellannahmen, Nullhypothese, Alternative, und Testergebnis.

# %% [markdown]
# * Modell: Messdifferenz der i-ten Messung ist negativ -> Gerät B misst grössere Werte
# * Nullhypothese: $H_0$: $\mu_d = \mu_0=0$
# * Alternative: $H_A$: $\mu_d < \mu_0$
# * Signifikanzniveau: $\alpha = 0.05$

# %%
ma <- c(120,265,157,187,219,288,156,205,163)
mb <- c(127,281,160,185,220,298,167,203,171)
t.test(ma,mb,alternative="less",paired=TRUE)
# Out:
# 	Paired t-test
#
# data:  ma and mb
# t = -2.7955, df = 8, p-value = 0.01168
# alternative hypothesis: true difference in means is less than 0
# 95 percent confidence interval:
#      -Inf -1.93449
# sample estimates:
# mean of the differences
#               -5.777778

# %% [markdown]
# * Testergebnis: Die Nullhypthese wird verworfen -> Gerät B misst grössere Werte

# %% [markdown]
# ## Aufgabe 10.3
# In der folgenden Tabelle sind die Kieferlängen von 10 männlichen und 10 weiblichen Goldschakalen eingetragen: Einige Kennzahlen: $\bar{x}_n = 113.4$, $\bar{y}_n = 108.6$, $\hat{\sigma}_x^2 = 13.82$,$\hat{\sigma}_y^2 = 5.16$
# ![series_10.3.png](attachment:3cb294e0-ef7f-49f6-b19a-db3504558290.png)

# %% [markdown]
# a) Handelt es sich um gepaarte oder ungepaarte Stichproben? Begründen Sie Ihre Antwort.

# %% [markdown]
# Es handelt sich um eine **ungepaarte** Stichprobe. Die Messungen sind nicht voreinander abhängig um ihre Aussage zu bestätigen.

# %% [markdown]
# b) Formulieren Sie Nullhypothese und Alternativhypothese.

# %% [markdown]
# * $H_0$: $\mu_x = \mu_{y}$
# * $H_A$: $\mu_y \neq \mu_{y}$, weil zweiseitig

# %% [markdown]
# c) Führen Sie den t-Test nun noch mit Hilfe von `R` durch. Geben Sie den resultierenden $p$-Wert sowie den daraus folgenden Testentscheid an.

# %%
jackals <- read.table(file = "s10_jackals.txt", header = TRUE) # Datensatz einlesen
jackals
# t-Test durchfuehren
t.test(jackals[, "M"], jackals[, "W"])
# Out:
#    M   W
# 1  120 110
# 2  107 111
# 3  110 107
# 4  116 108
# 5  114 110
# 6  111 105
# 7  113 107
# 8  117 106
# 9  114 111
# 10 112 111
# 	Welch Two Sample t-test
#
# data:  jackals[, "M"] and jackals[, "W"]
# t = 3.4843, df = 14.894, p-value = 0.00336
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  1.861895 7.738105
# sample estimates:
# mean of x mean of y
#     113.4     108.6

# %% [markdown]
# Der $p$-Wert $= 0.00336$ ist unter dem Signifikanzniveau, die Nullhypthese wird verworfen.

# %% [markdown]
# d) Führen Sie mit Hilfe von `R` einen Wilcoxon-Test durch. Geben Sie wiederum $p$-Wert und Testentscheid an.

# %%
wilcox.test(jackals[, "M"], jackals[, "W"], )
# Out:
# Warning message in wilcox.test.default(jackals[, "M"], jackals[, "W"], ):
# “cannot compute exact p-value with ties”
# 	Wilcoxon rank sum test with continuity correction
#
# data:  jackals[, "M"] and jackals[, "W"]
# W = 87.5, p-value = 0.004845
# alternative hypothesis: true location shift is not equal to 0

# %% [markdown]
# der $p$-Wert ist $0.004845$ ist auch unter dem Signifikanzniveau, weshalb die Nullhypthese verworfen wird.

# %% [markdown]
# e) Falls die Resultate der beiden Tests unterschiedlich ausgefallen wären, welchem würden Sie eher vertrauen? Weshalb?

# %% [markdown]
# Gemäss Skript soll der Wilcox-Test die grössere Macht (W'Keit Nullhypothese richtigweise zu verwerfen).

# %% [markdown]
# ## Aufgabe 10.4
# Ein U.S. Magazin, Consumer Reports, führte eine Untersuchung des Kalorien- und Salzgehaltes von verschiedenen Hotdog-Marken durch. Es gab drei verschiedene Typen von Hotdogs: Rind, „Fleisch” (Rind, Schwein, Geflügel gemischt) und Geflügel.
# Die Resultate unten führen den Kaloriengehalt verschiedener Marken von Rind- und Geflügel-Hotdogs auf.
# Haben die beiden Hotdog-Arten verschiedenen Kaloriengehalt?

# %%
rinds <- c(186,181,176,149,184,190,158,139,175,148,152,111,141,153,190,157,131,149,135,132)
gefluegel <- c(129,132,102,106,94,102,87,99,170,113,135,142,86,143,152,146,144)

# %% [markdown]
# a) Handelt es sich um einen gepaarten oder ungepaarten Test? Begründen Sie Ihre Antwort.

# %% [markdown]
# Es handelt sich um einen **ungepaarte** Stichprobe. Die Messungen könenn nicht eindeutig zugeordnet werden. enthalten die Reihen unterschiedlich viele Messungen.

# %% [markdown]
# b) Handelt es sich um einen ein- oder zweiseitigen Test? Begründen Sie Ihre Antwort.

# %% [markdown]
# um einen **zweiseitigen**; der Gehalt kann höher oder tiefer sein.

# %% [markdown]
# c) Formulieren Sie Null- und Alternativhypothese.

# %% [markdown]
# * $H_0$: $\mu_X=\mu_Y$ weil ungepaart, Mittelwerte vergleichen
# * $H_A$: $\mu_X\neq\mu_Y$

# %% [markdown]
# d) Berechnen Sie die Mittelwerte der beiden Testreihen. Welche Vermutung haben Sie?

# %%
mean(rinds)
mean(gefluegel)
# Out:
# [1] 156.85
# [1] 122.4706

# %% [markdown]
# Meine Vermutung ist, dass sie verschiedenen Kaloriengehalt haben.

# %% [markdown]
# e) Welchen Test würden Sie hier wählen: t-Test oder Wilcoxontest? Begründen Sie Ihre Antwort.

# %% [markdown]
# Einen Wilcoxontest, weil wir keine Angaben haben ob Daten normalverteilt.

# %% [markdown]
# f) Führen Sie den entsprechenden Test mit R durch. Interpretieren Sie p-Wert. Bei welcher Hotdog-Art ist der Kaloriengehalt grösser?

# %%
wilcox.test(rinds,gefluegel, paired=FALSE)
# Out:
# Warning message in wilcox.test.default(rinds, gefluegel, paired = FALSE):
# “cannot compute exact p-value with ties”
# 	Wilcoxon rank sum test with continuity correction
#
# data:  rinds and gefluegel
# W = 285.5, p-value = 0.0004549
# alternative hypothesis: true location shift is not equal to 0

# %% [markdown]
# der $p$-Wert ist unter der Signifikanzniveau. Die Nullhypotheses wird verworfen.

# %% [markdown]
# ## Aufgabe 10.5
# Im Jahr 2013 wurden im Rahmen einer internationalen Zusammenarbeit unter der Leitung der EAWAG in Dübendorf Konzentrationen von illegalen Substanzen im Ab- wasser von 42 europäischen Städten während einer Woche untersucht (Ort C. et all, Spatial differences and temporal changes in illicit drug use in Europe quantified by wastewater analysis, Addiction 2014 Aug).
#
# Dabei wurden an 7 aufeinanderfolgenden Tagen (6.-12. März) neben anderen Substanzen die medianen Konzentrationen von Ecstasy (MDMA) im Abwasser gemessenen. Aufgrund dieser Studie war eine Aussage einer vielgelesenen Schweizer Gratiszei- tung, dass in Zürich viel mehr Drogen konsumiert werden als anderswo.
#
# In der nachfolgenden Tabellle sind für die Städte Zürich und Basel die an den untersuchten Tagen ausgeschiedenen Mengen MDMA augeführt - die Werte finden Sie in der Datei `mdma.txt`. Die Angaben sind in mg pro 1000 Einwohner pro Tag. Nehmen Sie an, dass die täglichen Differenzen $D_i$ zwischen den pro tausend Einwohner ausgeschiedenen Mengen von MDMA im Abwasser von Zürich und Basel unabhängig voneinander normalverteilt mit Erwartungswert $\mu_D$ und Standardabweichung $\sigma_D$ sind.

# %%
mdma <- read.table(file = "s10_mdma.txt", header=FALSE) # Datensatz einlesen
colnames(mdma) <- c("Zürich","Basel")
mdma
# Out:
#   Zürich Basel
# 1  16.3  10.40
# 2  12.7   8.91
# 3  14.0  11.70
# 4  53.3  29.90
# 5 117.0  46.30
# 6  62.6  25.00
# 7  27.6  29.40

# %% [markdown]
# a) Schätzen Sie aus den Daten den Mittelwert und die Standardabweichung der Differenzen, d.h., $\hat{\mu}_D$ und $\hat{\sigma}_D$.

# %%
mdmaZ <- mdma[,"Zürich"]
mdmaB <- mdma[,"Basel"]
D <- mdmaZ - mdmaB
muD <- mean(D)
sigmaD <- sd(D)
muD
sigmaD
# Out:
# [1] 20.27
# [1] 26.2723

# %% [markdown]
# b) Handelt es sich um gepaarte oder ungepaarte Stichproben? Begründen Sie Ihre Antwort.

# %% [markdown]
# Es handelt sich um eine **gepaarte** Stichprobe. Die Messungen wurde am gleichen Tag gemacht.

# %% [markdown]
# c) Formulieren Sie die Nullhypothese und die Alternativhypothese, wenn Sie die Aussage der besagten Gratiszeitung überprüfen möchten.

# %% [markdown]
# * $H_0$: $\mu_0=0$
# * $H_A$: $\mu_Z > \mu_B$

# %% [markdown]
# d) Führen Sie einen statistischen Test mit Hilfe von R auf dem Signifikanzniveau 5 % durch, unter der Annahme, dass die Daten normalverteilt sind. Wie lautet die Teststatistik und wie ist diese unter der Nullhypothese verteilt?

# %%
t.test(mdmaZ, mdmaB, alternative="greater", paired=TRUE)
# Out:
# 	Paired t-test
#
# data:  mdmaZ and mdmaB
# t = 2.0413, df = 6, p-value = 0.04364
# alternative hypothesis: true difference in means is greater than 0
# 95 percent confidence interval:
#  0.9742245       Inf
# sample estimates:
# mean of the differences
#                   20.27

# %% [markdown]
# Der p-Wert ist unter dem Signifikanzniveau. Die Nullhypothese wird verworfen. In ZH wird statistisch mehr MDMA konsumiert.

# %% [markdown]
# e) Geben Sie das (einseitiges) 95 %-Vertrauensintervall für die Differenzen $D_i$ an (mit Hilfe von R). Wie interpretieren Sie dieses Vertrauensintervall?

# %% [markdown]
# Aus dem OutPut von d) $[\, 0.94224,\infty)$: mit 95% W'keit ist die wahre Differenz in diesem Intervall.

# %% [markdown]
# f) Führen Sie nun einen statistischen Test mit Hilfe von R auf dem Signifikanzniveau 5 % durch, unter der Annahme, dass die Daten nicht normalverteilt sind.

# %%
wilcox.test(mdmaZ,mdmaB, alternative="greater", paired=TRUE)
# Out:
# 	Wilcoxon signed rank exact test
#
# data:  mdmaZ and mdmaB
# V = 27, p-value = 0.01563
# alternative hypothesis: true location shift is greater than 0

# %% [markdown]
# Mit dem Wilcox-Test wird die Nullhypothese noch klarer verworfen.

# %% [markdown]
# ## Aufgabe 10.6
# Wir haben aus eigener Erfahrung das Gefühl, dass bei Ehepaaren der Mann eher älter ist als die Frau. Nun wollen wir statistisch untersuchen, ob dem so ist.
#
# Im Datensatz `mannfrau.csv` sind die Werte von Körpergrösse und Alter bei Mann und Frau von 170 britischen Ehepaaren aufgeführt. Die Körpergrösse ist in cm und das Alter in Jahren angegeben.
#
# Wir zeichnen den Boxplot für die Altersdifferenz der Ehepaare.

# %%
mf <- read.csv("mannfrau.csv")
diff <- mf$alter.mann - mf$alter.frau
boxplot(diff, col = "orange")
# Out:
# plot without title

# %% [markdown]
# Bei rund 50 % der Ehepaare liegt der Altersunterschied zwischen 0 und etwa 5 Jahren. Bei rund 25 % der Ehepaaren ist die Ehefrau älter als der Ehemann. Unsere Vermutung scheint zu stimmen, aber die Frage ist dann noch, ob der Unterschied statistisch signifikant ist.
#
# ### Aufbabe a)
# Wir wollen unsere Vermutung, dass die Männer bei Ehepaaren eher älter sind als die Frauen, ebenfalls mit einem Hypothesentest untersuchen.
# i) Wählen Sie einen gepaarten oder ungepaarten Test?

# %% [markdown]
# Ich wähle einen **gepaarten** Test. Zu einer Ehe gehören zwei Personen ;)

# %% [markdown]
# ii) Machen Sie einen ein- oder zweiseitigen Test?

# %% [markdown]
# Einen zweiseitigen, das Alter kann höher oder tiefer sein.

# %% [markdown]
# iii) Wir gehen von Normalverteilung der Daten aus. Führen Sie diesen Hypothesentest auf Signifikanzniveau von 5 % durch. Formulieren Sie die Null- und Alternativhypothese und führen Sie den Test mit Testentscheid auf einem Signifikanzniveau von 5 % durch. Führen Sie den Testentscheid noch mit dem Vertrauensintervall durch.

# %% [markdown]
# * $H_0$: $\mu_0 = 0$
# * $H_A$: $\mu \neq \mu_0$

# %%
t.test(mf$alter.mann, mf$alter.frau, paired=TRUE)
# Out:
# 	Paired t-test
#
# data:  mf$alter.mann and mf$alter.frau
# t = 7.1518, df = 169, p-value = 2.474e-11
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  1.618286 2.852302
# sample estimates:
# mean of the differences
#                2.235294

# %% [markdown]
# Die Nullhypthese wird verworfen. Statistisch sind die Ehemänner älter als die Ehefrauen. Der p-Wert ist nahe bei 0. Das Vertrauenintervall liegt zwischen $[\,1.618286, 2.852302]\,$, was heisst dass mit 95% W'keit das wahre Mittelwert (Altersunterschied) sich darin befindet.

# %% [markdown]
# iv) Wenn Sie nicht von Normalverteilung ausgehen, welchen Test wählen Sie? Führen Sie diesen Test durch.

# %%
wilcox.test(mf$alter.mann, mf$alter.frau, paired=TRUE)
# Out:
# 	Wilcoxon signed rank test with continuity correction
#
# data:  mf$alter.mann and mf$alter.frau
# V = 9460, p-value = 3.977e-12
# alternative hypothesis: true location shift is not equal to 0

# %% [markdown]
# Auch mit dem Wilcoxtest wird die Nullhypothese verworfen.

# %% [markdown]
# ### Aufgabe b)
# Wir untersuchen noch die Grössenunterschiede zwischen Frauen und Männer. Im Allgemeinen sind Männer grösser als Frauen. In England sind gemäss Wikipedia die Männer durchschnittlich 13 cm grösser als die Frauen.

# %% [markdown]
# i) Welcher Test ist hier angebracht (ein- oder zweisseitig, gepaart oder ungepaart)?

# %% [markdown]
# Es ist ein **zweiseitiger** Test angebracht weil wir prüfen wollen ob Männer grösser doder kleiner sind als Frauen. Der Test wird **ungepaarte** durchgeführt, weil die Messungen keine direkten Einfluss aufeinander haben.

# %% [markdown]
# ii) Formulieren Sie die Null- und Alternativhypothese.

# %% [markdown]
# * $H_0$: $\mu = 0$
# * $H_A$: $\mu > \mu_0$

# %% [markdown]
# iii) Wird die Aussage durch unseren Datensatz auf einem Signifikanzniveau von 5 % statistisch signifikant widerlegt? Führen Sie den Test mit Testentscheid durch. Wir nehmen an, dass die Körpergrössen normalverteilt sind.
#
# Führen Sie den Testentscheid noch mit dem Vertrauensintervall durch.

# %%
t.test(mf$groesse.mann, mf$groesse.frau, alternative="greater", paired=FALSE)
# Out:
# 	Welch Two Sample t-test
#
# data:  mf$groesse.mann and mf$groesse.frau
# t = 18.017, df = 336.53, p-value < 2.2e-16
# alternative hypothesis: true difference in means is greater than 0
# 95 percent confidence interval:
#  11.40913      Inf
# sample estimates:
# mean of x mean of y
#  172.8471  160.2882

# %% [markdown]
# Die Nullhypthese wird statistisch signifikant widerlegt. Männer sind mit 95% W'keit im Mittel min. 11.40913cm grösser.

# %% [markdown]
# ## Aufgabe 10.7
# Die Körpertemperatur von 10 Patienten wird zum Zeitpunkt der Verabreichung eines Medikaments ($T_1$) und 2 Stunden später ($T_2$) gemessen. Es soll geprüft werden, ob dieses Medikament eine fiebersenkende Wirkung hat.

# %%
temp1 <- c(39.1, 39.3, 38.9, 40.6, 39.5, 38.4, 38.6, 39.0, 38.6, 39.2)
temp2 <- c(38.1, 38.3, 38.8, 37.8, 38.2, 37.3, 37.6, 37.8, 37.4, 38.1)

# %% [markdown]
# a) Handelt es sich um einen gepaarten oder ungepaarten Test? Begründen Sie Ihre Antwort.

# %% [markdown]
# Es handelt sich um einen **gepaarten** Test. Die Temperaturen lassen sich eindeutig den Personen zuordnen.

# %% [markdown]
# b) Handelt es sich um einen ein- oder zweiseitigen Test? Begründen Sie Ihre Antwort.

# %% [markdown]
# Es handelt sich um einen **einseitigen** Test, weil überprüft werden soll ob das Medikament eine fiebersenkende Wirkung hat.

# %% [markdown]
# c) Formulieren Sie Null- und Alternativhypothese.

# %% [markdown]
# * $H_0$: $\mu = \mu_0$
# * $H_A$: $\mu < \mu_0$

# %% [markdown]
# d) Wir nehmen an, die Daten seien normalverteilt. Welchen Test wählen Sie? Führen Sie den Test mit R auf Signifikanzniveau 5 % durch.

# %%
t.test(temp1,temp2, alternative="less",paired=TRUE)
# Out:
# 	Paired t-test
#
# data:  temp1 and temp2
# t = 5.6569, df = 9, p-value = 0.9998
# alternative hypothesis: true difference in means is less than 0
# 95 percent confidence interval:
#      -Inf 1.562375
# sample estimates:
# mean of the differences
#                    1.18

# %% [markdown]
# Der p-Wert ist nahe bei 1. Die Nullhyothese wird nicht verworfen. Mit hoher statistischer signifkanz wirkt das Medikament fiebersenked.

# %% [markdown]
# e) Wenn wir nicht davon ausgehen können, dass die Daten normalverteilt sind, welchen Test wählen Sie? Führen Sie diesen auf Signifikanzniveau 5 % durch.

# %%
wilcox.test(temp1,temp2, alternative="less",paired=TRUE)
# Out:
# Warning message in wilcox.test.default(temp1, temp2, alternative = "less", paired = TRUE):
# “cannot compute exact p-value with ties”
# 	Wilcoxon signed rank test with continuity correction
#
# data:  temp1 and temp2
# V = 55, p-value = 0.9979
# alternative hypothesis: true location shift is less than 0

# %% [markdown]
# Der Unterschied kommt von der grösseren Unsicherheit, weil wir nicht wissen ob die Daten normalverteilt sind.

# %% [markdown]
# ## Aufgabe 10.8
# Betrachten Sie einen einseitigen t-Test von $H_0$ : $\mu = 0$ gegen $H_A$ : $\mu > 0$ zum Niveau $0.05$. Obwohl die beobachteten $n$ Datenpunkte einen empirischen Mittelwert grösser Null haben, ergeben die Berechnungen, dass die Nullhypothese nicht verworfen wird.
#
# Entscheiden Sie, ob folgende Aussagen *wahr* oder *falsch* sind. Machen Sie eine vernünftige Skizze, wo Sie die relevanten Grössen einzeichnen.

# %% [markdown]
# a) Man verwirft $H_0$ für kein Niveau $\alpha < 0.05$.

# %% [markdown]
# Die Aussage ist **falsch**. Die Nullhypothese wir für $\alpha < 0.05$ verworfen.

# %% [markdown]
# b) Es gibt ein Niveau $\alpha < 1$, bei dem man $H_0$ verwirft.

# %% [markdown]
# Die Aussagbe ist **wahr**, $H_0$ wird praktisch immer verworfen.

# %% [markdown]
# c) Der p-Wert ist strikt kleiner als 0.5.

# %% [markdown]
# Die Aussage ist **falsch**, der $p$-Wert liegt zwischen 0 und 1.

# %% [markdown]
# d) Führt man statt eines einseitigen einen zweiseitigen Test zum Niveau $0.05$ durch, verwirft man $H_0$ nicht.

# %% [markdown]
# Die Aussage ist **falsch**, das Niveau definiert ab wann Abweichungen zu gross sind um einem wahren Mittelwert anzugehören, egal ob ein- oder zweiseitiger Test.

# %% [markdown]
# e) Wenn man die Daten immer öfter kopiert (d. h., man betrachtet jeden Datenpunkt $k$-Mal, so dass man insgesamt $k * n$ Datenpunkte erhält), verwirft man $H_0$ für ein grosses $k$ beim Niveau $0.05$.

# %% [markdown]
# Die Aussage ist ??

# %% [markdown]
# ![s10_8.1.png](attachment:d45bdd4f-befb-4b2c-af49-cdf885c80801.png)
# ![s10_8.2.png](attachment:b5836b45-6f81-46ff-a224-44339b506f28.png)
# ![s10_8.3.png](attachment:00904a4b-e799-49d8-92da-5246e8184f91.png)
# ![s10_8.4.png](attachment:3753fc17-c9ae-475a-8371-efecd4adc37a.png)
